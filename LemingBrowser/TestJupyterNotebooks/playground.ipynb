# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

from mainfunctions import *
import ROOT

# Native ROOT windows
ROOT.gROOT.SetBatch(False)
ROOT.PyConfig.StartGUIThread = False
init_canvas_events()
# %jsroot off

# %%
root_list1 = get_loaf_remote_directory_root_files_list(runspec="3500-3561",print_folder_summary=False)

# %%
temperature_rdataframe = get_general_rdataframe(
    root_list1,
    "temperatures",
    number_of_threads= 8
)

# %%
all_hist = get_loaf_histograms(
    dataframe=temperature_rdataframe,
    dataframe_labels=["DataFrame1"],
    quantities=["temp_50K","temp_4K","temp_still"]
)

# %%
plot_loaf_histograms(all_hist)

# %%
plot_loaf_histograms({
    "Test1": all_hist["temp_4K"]["DataFrame1"],
    "Test2": all_hist["temp_50K"]["DataFrame1"]
    },show_provenance=True)

# %%
log_histograms(all_hist["temp_4K"]["DataFrame1"])

# %%
plot_loaf_histograms({
    "Test1": all_hist["temp_4K"]["DataFrame1"],
    },show_provenance=True)

# %%
plot_loaf_histograms(all_hist,show_provenance=True)

# %%
log_histograms([all_hist["temp_4K"]["DataFrame1"]])

# %%
rdataframe1 = get_loaf_diagnostics_rdataframe(
    selected_files = root_list1,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
all_hist = get_loaf_histograms(
    dataframe=rdataframe1,
    dataframe_labels=["DataFrame1"],
    quantities=["pileupType","tC63vsC62","hasPileup"]
)

# %%
plot_loaf_histograms(all_hist,show_provenance=True)

# %%
log_histograms(histograms=[all_hist["pileupType"]["DataFrame1"],all_hist["tC63vsC62"]["DataFrame1"]],save=True,output_format="svg")

# %%
root_list2 = get_local_directory_root_files_list(runspec="3500-3561",local_directory="/data0/kfritzalas",print_folder_summary=False)

# %%
rdataframe2 = get_loaf_diagnostics_rdataframe(
    selected_files = root_list2,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=rdataframe2,
    dataframe_labels=["DataFrame1"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"],
    saveHistograms=True,
    outputFileName="testfile"
)

# %%
plot_loaf_histograms(all_histograms,show_provenance=True)

# %%
log_histograms(all_histograms["hasPileup:pileupType"]["DataFrame1"])

# %%
rdataframe2 = apply_global_filter([rdataframe2], "pileupType > 3")

# %%
all_histograms = get_loaf_histograms(
    dataframe=rdataframe2,
    dataframe_labels=["DataFrame1"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"],
    saveHistograms=True,
    outputFileName="testfile"
)

# %%
plot_loaf_histograms(all_histograms,show_provenance=True)

# %%
log_histograms(all_histograms["hasPileup:pileupType"]["DataFrame1"])

# %%
plot_loaf_histograms(
    histograms=all_histograms
)

# %%
plot_loaf_histograms(
    histograms=all_histograms["tC63vsC62"],
    saveCanvas=True,
    outputFileName="test",
    outputFormats=[
        "pdf",
        "png",
        "svg",
        "tiff",
        "gif",
        "bmp",
        "ps",
        "eps",
        "root",
        "c"
    ],
    show_provenance=True
)

# %%
root_list3 = get_local_directory_root_files_list(runspec="3500-3531",local_directory="/data0/kfritzalas",print_folder_summary=False)

# %%
rdataframe3 = get_loaf_diagnostics_rdataframe(
    selected_files = root_list3,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[rdataframe2,rdataframe3],
    dataframe_labels=["DataFrame1","DataFrame2"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"]
)

# %%
plot_loaf_histograms({
        "tC63vsC62": all_histograms["tC63vsC62"]["DataFrame1"],
        "pileupType": all_histograms["pileupType"]["DataFrame1"]
    },
title="tC63vsC62 & pileupType Distribution",
x_axis_title="tC63vsC62 & pileupType"
)

# %%
root_list4 = get_loaf_remote_directory_root_files_list(runspec="3430",print_folder_summary=False)
root_list5 = get_loaf_remote_directory_root_files_list(runspec="3431",print_folder_summary=False)

rdataframe4 = get_loaf_diagnostics_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_loaf_diagnostics_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[rdataframe4,rdataframe5],
    dataframe_labels=["DataFrame4","DataFrame5"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"]
)

# %%
plot_loaf_histograms(all_histograms["hasPileup"])

# %%
filtered_rdataframe4 = apply_global_filter(
    rdataframe4,
    "pileupType > 5"
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[filtered_rdataframe4,rdataframe5],
    dataframe_labels=["DataFrame4","DataFrame5"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"]
)

# %%
plot_loaf_histograms(all_histograms["pileupType"]["DataFrame4"])

# %%
filtered_rdataframe44 = apply_global_filter(
    rdataframe4,
    "tC63vsC62 > 10"
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[filtered_rdataframe44,rdataframe5],
    dataframe_labels=["DataFrame4","DataFrame5"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"]
)

# %%
plot_loaf_histograms(all_histograms["tC63vsC62"]["DataFrame4"])

# %%
filtered_rdataframe444 = apply_global_filter(
    rdataframe4,
    "tC63vsC62 > 0 && tC63vsC62 < 25.1"
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[filtered_rdataframe444,rdataframe5],
    dataframe_labels=["DataFrame4","DataFrame5"],
    quantities=["pileupType","tC63vsC62","hasPileup","hasPileup:hasPileup","hasPileup:pileupType"]
)

# %%
plot_loaf_histograms(all_histograms["tC63vsC62"]["DataFrame4"])

# %%
root_list4 = get_loaf_remote_directory_root_files_list(runspec="3500-3561",print_folder_summary=False)
root_list5 = get_loaf_remote_directory_root_files_list(runspec="3500-3550",print_folder_summary=False)



rdataframe4 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
filter_rdataframe_det1 = apply_global_filter(
    rdataframe4,
    'Idetname == "Muon_Entrance"'
)
filter_rdataframe_det2 = apply_global_filter(
    rdataframe5,
    'Idetname == "Muon_Entrance"'
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[filter_rdataframe_det1,filter_rdataframe_det2],
    dataframe_labels=["DataFrame4","DataFrame5"],
    quantities=["Itime","Iedeposit","IDriftTime"],
    bins= [2000,4096,2000],
    ranges=[
        (-10000,10000),
        (0.0,4096),
        (-10000,10)
    ]
)

# %%
plot_loaf_histograms(all_histograms,show_provenance=True,saveCanvas=True,outputFileName="kosmas",outputFormats="svg")

# %%
log_histograms(all_histograms["Iedeposit"]["DataFrame4"])

# %%
plot_loaf_histograms(all_histograms["Itime"])

# %%
root_list4 = get_local_directory_root_files_list(runspec="3500-3561",local_directory="/data0/kfritzalas",print_folder_summary=False)
root_list5 = get_local_directory_root_files_list(runspec="3500-3551",local_directory="/data0/kfritzalas",print_folder_summary=False)

rdataframe4 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
detector_dataframe_filtered = apply_per_detector_filter(
    rdataframe4,
    ["LN1","LN2"],
    ["Iedeposit > 200", "Iedeposit < 200"]
)

filter_rdataframe_det1 = apply_global_filter(
    detector_dataframe_filtered,
    'Idetname == "LN1"'
)
filter_rdataframe_det2 = apply_global_filter(
    rdataframe5,
    'Idetname == "LN2"'
)
filter_rdataframe_det3 = apply_global_filter(
    detector_dataframe_filtered,
    'Idetname == "LF1"'
)
filter_rdataframe_det4 = apply_global_filter(
    detector_dataframe_filtered,
    'Idetname == "Muon_Entrance"'
)
filter_rdataframe_det5 = apply_global_filter(
    rdataframe4,
    'Idetname == "Muon_Entrance"'
)
rdataframe4 = apply_global_filter(
    rdataframe4,
    'Iedeposit > 500 && Idetname == "Muon_Entrance"'
)
rdataframe4 = apply_global_filter(
    rdataframe4,
    'Itime > -5 && Idetname == "Muon_Entrance"'
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        rdataframe4,
        filter_rdataframe_det2,
        filter_rdataframe_det3,
        filter_rdataframe_det4,
        filter_rdataframe_det5
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "DataFrame6",
        "DataFrame7",
        "DataFrame8"
    ],
    quantities=[
        "Itime",
        "Iedeposit",
        "IDriftTime",
        "Itime:Iedeposit",
        "Iedeposit:Itime",
        "IDriftTime:Iedeposit",
    ],
    bins=[
        2000,          # Itime
        4096,          # Iedeposit
        2000,          # IDriftTime
        (2000, 4096),  # Itime:Iedeposit -> (x_bins, y_bins)
        (4096,2000),
        (2000, 4096),  # IDriftTime:Iedeposit -> (x_bins, y_bins)
    ],
    ranges=[
        (-10000, 10000),                 # Itime
        (0.0, 4096),                     # Iedeposit
        (-10000, 10),                    # IDriftTime
        ((-10000, 10000),(0, 4096)), # Itime:Iedeposit
        ((0.0, 4096),(-10000, 10000)), # Iedeposit:Itime
        ((0.0, 4096), (-10000, 10)),    # IDriftTime:Iedeposit
    ],
    saveHistograms=True,
    outputFileName="test"
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        rdataframe4,
        filter_rdataframe_det2,
        filter_rdataframe_det3,
        filter_rdataframe_det4,
        filter_rdataframe_det5
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "DataFrame6",
        "DataFrame7",
        "DataFrame8"
    ],
    quantities=[
        "Itime",
        "Iedeposit",
        "IDriftTime",
    ],
    bins=[
        2000,          # Itime
        4096,          # Iedeposit
        2000,          # IDriftTime
    ],
    ranges=[
        (-10000, 10000),                 # Itime
        (0.0, 4096),                     # Iedeposit
        (-10000, 10),                    # IDriftTime
    ],
)

# %%
plot_loaf_histograms(all_histograms,show_provenance=True)

# %%
plot_loaf_histograms(all_histograms["Itime:Iedeposit"]["DataFrame5"],show_provenance=True)

# %%
plot_loaf_histograms(all_histograms["Itime"],show_provenance=True)

# %%
plot_loaf_histograms(
    {
        "LN1": all_histograms["Iedeposit"]["DataFrame4"],
        "LN2": all_histograms["Iedeposit"]["DataFrame5"]
    },
    title="Iedeposit",
    x_axis_title="Iedeposit"
)

# %%
normalized = Normalize_Histograms([all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame5"]],
                                  saveHistograms=True,outputFileName="test1")
lifetime = lifetime_correction_histograms(normalized,
                                          saveHistograms=True,outputFileName="test2")
background = background_subtraction_histograms(lifetime,
                                               saveHistograms=True,outputFileName="test3")

muSR = calculate_muSR(hist1_or_groups=all_histograms["Itime"]["DataFrame4"],hist2=all_histograms["Itime"]["DataFrame5"],
                      saveHistograms=True,outputFileName="test4")

muSR2 = calculate_muSR(hist1_or_groups=[(all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame5"])],
                      saveHistograms=True,outputFileName="test5")

added_histo = addHistograms([all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame5"]],
                           saveHistograms=True,outputFileName="test6" )

sub_histo = subtractHistograms([all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame5"]],
                           saveHistograms=True,outputFileName="test7" )

mult_histo = multiplyHistograms([all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame5"]],
                           saveHistograms=True,outputFileName="test8" )

div_histo = devideHistograms([all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame5"]],
                           saveHistograms=True,outputFileName="test9" )

div_hist2 = devideHistograms([all_histograms["Itime"]["DataFrame4"],all_histograms["Itime"]["DataFrame4"]],
                           saveHistograms=True,outputFileName="test10" )

plot_loaf_histograms(
    {
        "LN1": all_histograms["Itime"]["DataFrame4"],
    },
)
plot_loaf_histograms(
    {
        "LN1": normalized[1],
    },
)
plot_loaf_histograms(
    {
        "LN1": lifetime[1],
    },
)
plot_loaf_histograms(
    {
        "LN1": background[1],
    },
)
plot_loaf_histograms(
    {
        "LN1": muSR,
    },
)
plot_loaf_histograms(
    {
        "LN1": muSR2[0],
    },
)
plot_loaf_histograms(
    {
        "LN1": added_histo,
    },
)
plot_loaf_histograms(
    {
        "LN1": sub_histo,
    },
)
plot_loaf_histograms(
    {
        "LN1": mult_histo,
    },
)
plot_loaf_histograms(
    {
        "LN1": div_histo,
    },
)
plot_loaf_histograms(
    {
        "LN1": div_hist2,
    },
)

# %%
log_histograms(added_histo)

# %%
log_histograms([muSR,normalized[0],normalized[1],lifetime[0],lifetime[1]])

# %%
plot_loaf_histograms(muSR,show_provenance=True)

# %%
plot_loaf_histograms({
    "Test1":muSR,
    "Test2":normalized[0]},show_provenance=True)

# %%
h4 = all_histograms["Itime"]["DataFrame4"]

before = [
    (
        h4.GetBinContent(i),
        h4.GetBinError(i)
    )
    for i in range(0, h4.GetNbinsX() + 2)
]

result = calculate_muSR(
    [(h4, all_histograms["Itime"]["DataFrame5"])],
    saveHistograms=False,
    outputFileName=None
)

after = [
    (
        h4.GetBinContent(i),
        h4.GetBinError(i)
    )
    for i in range(0, h4.GetNbinsX() + 2)
]

print(before == after)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        filter_rdataframe_det5
    ],
    dataframe_labels=[
        "DataFrame5",
    ],
    quantities=[
        "Itime",
        "Iedeposit",
        "IDriftTime",
    ],
    bins=[
        2000,          # Itime
        4096,          # Iedeposit
        2000,          # IDriftTime
    ],
    ranges=[
        (-10000, 10000),                 # Itime
        (0.0, 4096),                     # Iedeposit
        (-10000, 1000),                    # IDriftTime
    ],
    saveHistograms=True,
    outputFileName="testfile"
)

# %%
plot_loaf_histograms(all_histograms["Iedeposit"])

# %%
plot_loaf_histograms(all_histograms["Itime:Iedeposit"]["DataFrame6"])
plot_loaf_histograms(all_histograms["Itime"]["DataFrame6"])

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        filter_rdataframe_det1,
        filter_rdataframe_det2,
        filter_rdataframe_det3
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "DataFrame6"
    ],
    quantities=[
        "Itime",
        "Iedeposit",
        "IDriftTime"
    ],
    bins=[
        2000,          # Itime
        4096,          # Iedeposit
        2000,          # IDriftTime
    ],
    ranges=[
        (-10000, 10000),                 # Itime
        (0.0, 4096),                     # Iedeposit
        (-10000, 10),                    # IDriftTime
    ],
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        filter_rdataframe_det1
    ],
    dataframe_labels=[
        "DataFrame4",
    ],
    quantities=[
        "Itime",
        "Iedeposit",
        "IDriftTime"
    ],
    bins=[
        2000,          # Itime
        4096,          # Iedeposit
        2000,          # IDriftTime
    ],
    ranges=[
        (-10000, 10000),                 # Itime
        (0.0, 4096),                     # Iedeposit
        (-10000, 10),                    # IDriftTime
    ],
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        filter_rdataframe_det1,
        filter_rdataframe_det2,
        filter_rdataframe_det3
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "DataFrame6"
    ],
    quantities=[
        "Itime",
        "Iedeposit",
        "IDriftTime"
    ],
    bins=[
        2000,          # Itime
        4096,          # Iedeposit
        2000,          # IDriftTime
    ],
    ranges=[
        (-10000, 10000),                 # Itime
        (0.0, 4096),                     # Iedeposit
        (-10000, 10),                    # IDriftTime
    ],
)

# %%
plot_loaf_histograms(all_histograms)

# %%
root_list4 = get_local_directory_root_files_list(runspec="3460-3530",local_directory="/data0/kfritzalas/tram",print_folder_summary=False)
root_list5 = get_local_directory_root_files_list(runspec="3460-3521",local_directory="/data0/kfritzalas/tram",print_folder_summary=False)

rdataframe4 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
all_histograms = get_tram_histograms(
    dataframe=[
        rdataframe4,
        rdataframe5,
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
    ],
    quantities=[
        "Y2L",
        "Y1L",
        "Y1L:Z1L"
    ],
)

# %%
plot_tram_histograms(all_histograms)

# %%
plot_tram_histograms(all_histograms,show_provenance=True)

# %%
root_list4 = get_tram_remote_directory_root_files_list(runspec="3460-3530",
                                                       remote_directory="data0/leming/BT2025/kosmas/tram_new",
                                                       print_folder_summary=False)
root_list5 = get_tram_remote_directory_root_files_list(runspec="3460-3521",
                                                       remote_directory="data0/leming/BT2025/kosmas/tram_new",
                                                       print_folder_summary=False)

rdataframe4 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
for q in ["Z1L", "Z2L", "Z1R", "Z2R"]:
    print(q, rdataframe4.GetColumnType(q))

# %%
filter_data = apply_global_filter(
    rdataframe4,
    "(abs(Z1L-Z2L) < 0.2)"
)
filter_data2 = apply_global_filter(
    rdataframe4,
    "Z1L>10"
)

all_histograms = get_tram_histograms(
    dataframe=[
        rdataframe4,
        rdataframe5,
        filter_data,
        filter_data2
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "filter_data",
        "filter_data2"
    ],
    quantities=[
        "Z2R",
        "Z1R",
        "Z1L",
        "Z2L"
    ],
)

# %%
plot_tram_histograms(all_histograms)

# %%
root_list4 = get_tram_remote_directory_root_files_list(runspec="3460-3530",
                                                       remote_directory="data0/leming/BT2025/kosmas/tram_new",
                                                       print_folder_summary=False)
root_list5 = get_tram_remote_directory_root_files_list(runspec="3460-3521",
                                                       remote_directory="data0/leming/BT2025/kosmas/tram_new",
                                                       print_folder_summary=False)

rdataframe4 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list4,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list5,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
debug = (
    rdataframe4
    .Define("__nZ1L", "Z1L.size()")
    .Define("__nZ2L", "Z2L.size()")
    .Define("__nZ1R", "Z1R.size()")
    .Define("__nZ2R", "Z2R.size()")
)

debug.Filter(
    "Z1L.size() == Z2L.size() && "
    "(Z1R.size() != Z1L.size() || Z2R.size() != Z1L.size())"
).Display(
    ["Z1L", "Z2L", "Z1R", "Z2R", "Y1L"],
    20
).Print()

# %%
bad_y = rdataframe4.Filter(
    "ROOT::VecOps::Any(abs(Z1L-Z2L) < 0.2) && "
    "Y1L.size() != Z1L.size()"
)

print("bad Y1L surviving events:", bad_y.Count().GetValue())

# %%
bad_z1r = rdataframe4.Filter(
    "ROOT::VecOps::Any(abs(Z1L-Z2L) < 0.2) && "
    "Z1R.size() != Z1L.size()"
)

bad_z2r = rdataframe4.Filter(
    "ROOT::VecOps::Any(abs(Z1L-Z2L) < 0.2) && "
    "Z2R.size() != Z1L.size()"
)

print("bad Z1R surviving events:", bad_z1r.Count().GetValue())
print("bad Z2R surviving events:", bad_z2r.Count().GetValue())

# %%
plot_tram_histograms(all_histograms)

# %%
plot_tram_histograms(all_histograms, show_provenance=True)

# %%
all_histograms = get_tram_histograms(
    dataframe=[
        rdataframe4,
        rdataframe5,
        filter_data,
        filter_data2
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "filter_data",
        "filter_data2"
    ],
    quantities=[
        "Y2L",
        "Y1L",
        "Z1L",
        "edep_Y1L",
        "Y1L:Z1L",
        "Z1L:Y1L",
        "Z2L:Y2L",
        "edep_Y1L:edep_Z1L",
        "edep_Y1L:edep_Y2L"
    ],
)

# %%
plot_tram_histograms(all_histograms,show_provenance=True)

# %%
plot_tram_histograms(all_histograms["Z1L:Y1L"]["DataFrame4"],show_3d=True,saveCanvas=True,outputFileName="test",outputFormats="pdf")

# %%
plot_tram_histograms(all_histograms["Y1L"]["DataFrame4"])

# %%
root_coinc = get_local_directory_root_files_list(runspec="3500-3561",local_directory="/data0/kfritzalas/tram",print_folder_summary=False)

rdataframe4 = get_tram_t2_clusters_rdataframe(
    selected_files = root_coinc,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
coinc_rdataframe = apply_tram_straight_coincidence(
    dataframes=rdataframe4,
    settings={
        # Delta Z
        "delta_z_max_left": 0.2,
        "delta_z_max_right": 0.2,

        # Z1L position
        "z1_min_left": 12.0,
        "z1_max_left": 15.0,

        # Z2L position
        "z2_min_left": 12.0,
        "z2_max_left": 15.0,

        # Z1L energy
        "z1_edep_min_left": None,
        "z1_edep_max_left": None,

        # Z2L energy
        "z2_edep_min_left": None,
        "z2_edep_max_left": None,

        # Z1L time
        "z1_time_min_left": None,
        "z1_time_max_left": None,

        # Z2L time
        "z2_time_min_left": None,
        "z2_time_max_left": None,

        # Z1R position
        "z1_min_right": 12.0,
        "z1_max_right": 15.0,

        # Z2R position
        "z2_min_right": 12.0,
        "z2_max_right": 15.0,

        # Z1R energy
        "z1_edep_min_right": None,
        "z1_edep_max_right": None,

        # Z2R energy
        "z2_edep_min_right": None,
        "z2_edep_max_right": None,

        # Z1R time
        "z1_time_min_right": None,
        "z1_time_max_right": None,

        # Z2R time
        "z2_time_min_right": None,
        "z2_time_max_right": None,
    }
)
coinc_rdataframe_atomic = apply_global_filter(
    coinc_rdataframe,
    "hasAtomicHit == 1"
)

# %%
all_histograms = get_tram_histograms(
    dataframe=[
        coinc_rdataframe,
        coinc_rdataframe_atomic
    ],
    dataframe_labels=[
        "coincidence",
        "coinc_rdataframe_atomic"
    ],
    quantities=[
        "StraightTimeZ1L",
        "StraightTimeZ1R",
    ],
)

# %%
plot_tram_histograms(all_histograms,show_provenance=True)

# %%
normalized_hist1 = Normalize_Histograms(all_histograms["StraightTimeZ1L"]["coincidence"])
lifetime_hist1 = lifetime_correction_histograms(all_histograms["StraightTimeZ1L"]["coincidence"])

normalized_hist2 = Normalize_Histograms(all_histograms["StraightTimeZ1L"]["coinc_rdataframe_atomic"])
lifetime_hist2 = lifetime_correction_histograms(all_histograms["StraightTimeZ1L"]["coinc_rdataframe_atomic"])

# %%
log_histograms([lifetime_hist1,lifetime_hist2])

# %%
plot_tram_histograms(lifetime_hist1)

# %%
plot_tram_histograms(lifetime_hist1,show_provenance=True)

# %%
plot_tram_histograms(lifetime_hist2)

# %%
#Local Project + Local Files
rdataframe_vol1 = get_rdataframe_volume_cuts(
    runspec="3499-3541",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)

# %%
#Local Project + Remote Files
rdataframe_vol2 = get_rdataframe_volume_cuts(
    runspec="3499-3541",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)

# %%
#Remote tram project + remote files
rdataframe_vol3 = get_rdataframe_volume_cuts(
    runspec="3499-3541",
    project_directory="data0/leming/BT2025/kosmas/tram_software/tram",
    isRemoteProjectDirectory= True,
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)

# %%
all_histograms = get_tram_histograms(
    dataframe=[rdataframe_vol1,rdataframe_vol2,rdataframe_vol3],
    dataframe_labels=["rdataframe_vol1","rdataframe_vol2","rdataframe_vol3"],
    quantities="time_Y1L",
    bins=[100],
    ranges=(-1000,15000)
)

# %%
all_histograms = get_tram_histograms(
    dataframe=[rdataframe_vol1,],
    dataframe_labels=["rdataframe_vol1",],
    quantities="time_Y1L",
    bins=[100],
    ranges=(-1000,15000)
)

# %%
all_histograms = get_tram_histograms(
    dataframe=[rdataframe_vol3,],
    dataframe_labels=["rdataframe_vol3",],
    quantities="time_Y1L",
    bins=[100],
    ranges=(-1000,15000)
)

# %%
plot_tram_histograms(all_histograms)

# %%
log_histograms(all_histograms["time_Y1L"]["rdataframe_vol3"])

# %%
plot_tram_histograms(all_histograms,show_provenance=True)

# %%
log_histograms(all_histograms["time_Y1L"]["rdataframe_vol1"])

# %%
root_list4 = get_local_directory_root_files_list(runspec="3500-3561",local_directory="/data0/kfritzalas",print_folder_summary=False)
root_list5 = get_local_directory_root_files_list(runspec="3500-3551",local_directory="/data0/kfritzalas",print_folder_summary=False)

rdataframe4 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
filter1_dataframe = apply_global_filter(
    rdataframe4,
    'Idetname == "LN1"'
)
filter2_dataframe = apply_column_filter(
    filter1_dataframe,
    "Iedeposit > 200"
)
filter3_dataframe = apply_global_filter(
    filter1_dataframe,
    "Iedeposit > 200"
)
filter4_dataframe = apply_detector_event_filter_cut_rdataframe(
    rdataframe4,
    "LN1",
    "Iedeposit > 200"
)
filter5_dataframe = apply_global_filter(
    filter4_dataframe,
    'Idetname == "LN1"'
)
filter6_dataframe = apply_global_filter(
    rdataframe4,
    'Idetname == "LN2"'
)
filter7_dataframe = apply_global_filter(
    filter4_dataframe,
    'Idetname == "LN2"'
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[
        filter1_dataframe,
        filter2_dataframe,
        filter3_dataframe,
        filter5_dataframe,
        filter6_dataframe,
        filter7_dataframe
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
        "DataFrame6",
        "DataFrame7",
        "DataFrame8",
        "DataFrame9",
    ],
    quantities=[
        "Itime",
    ],
    bins=[
        2000,          # Itime
    ],
    ranges=[
        (-10000, 10000), # Itime
    ],
)

# %%
plot_loaf_histograms(all_histograms["Itime"]["DataFrame7"],show_provenance=True)

# %%
plot_loaf_histograms(
    {
        "Case1": all_histograms["Itime"]["DataFrame8"],
        "Case2": all_histograms["Itime"]["DataFrame9"],
    }
)

# %%
log_histograms([all_histograms["Itime"]["DataFrame9"],all_histograms["Itime"]["DataFrame8"]])

# %%
log_histograms(all_histograms["Itime"]["DataFrame7"])

# %%
log_histograms(all_histograms["Itime"]["DataFrame5"])

# %%
root_list4 = get_local_directory_root_files_list(runspec="3500-3561",local_directory="/data0/kfritzalas",print_folder_summary=False)
root_list5 = get_local_directory_root_files_list(runspec="3500-3551",local_directory="/data0/kfritzalas",print_folder_summary=False)

rdataframe4 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_loaf_t2_tram_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
filter1_dataframe = apply_global_filter(
    rdataframe4,
    'Idetname == "Muon_Entrance"'
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[filter1_dataframe],dataframe_labels=["dataframe1"],quantities=["Iedeposit"],
    bins=[4096],ranges=[(0.0,4096.0)])

# %%
log_histograms(all_histograms["Iedeposit"]["dataframe1"])

# %%
coinc_dataframe = apply_loaf_coincidence_old(
    rdataframe4,
    ["LN3", "LF3"]
)
coinc_dataframe = apply_global_filter(
    coinc_dataframe,
    "time_coinc >= 0"
)

# %%
coinc_dataframe2 = apply_loaf_coincidence_old(
    rdataframe4,
    ["LN3", "LF3","Atomic"]
)

# %%
all_histograms = get_loaf_histograms(
    dataframe=[coinc_dataframe,coinc_dataframe2],
    dataframe_labels=["coinc_dataframe","coinc_dataframe2"],
    quantities=["time_coinc"],
    bins=[2000],
    ranges=[
        (-10000.0, 10000.0),
    ],
)

# %%
plot_loaf_histograms(all_histograms,show_provenance=True)

# %%
plot_loaf_histograms(all_histograms["time_coinc"]["coinc_dataframe"])

# %%
log_histograms([all_histograms["time_coinc"]["coinc_dataframe"],all_histograms["time_coinc"]["coinc_dataframe2"]])

# %%
root_list4 = get_tram_remote_directory_root_files_list(runspec="3500-3561",print_folder_summary=False,
                                                       remote_directory = "data0/leming/BT2025/kosmas/tram_new",)
root_list5 = get_tram_remote_directory_root_files_list(runspec="3500-3551",print_folder_summary=False,
                                                       remote_directory = "data0/leming/BT2025/kosmas/tram_new")

rdataframe4 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list4,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)
rdataframe5 = get_tram_t2_clusters_rdataframe(
    selected_files = root_list5,
    number_of_threads = 8,
    add_run_subrun_columns = False,
    debug_preview_dataframe = False
)

# %%
all_histograms = get_tram_histograms(
    dataframe=[
        rdataframe4,
        rdataframe5,
    ],
    dataframe_labels=[
        "DataFrame4",
        "DataFrame5",
    ],
    quantities=[
        "MuonEntranceEnergy",
        "MuonEntranceTime"
    ],
    bins=[
        4096,
        2000,          # Itime
    ],
    ranges=[
        (0.0,4096.0),
        (-10000, 10000), # Itime
    ],
)

# %%
plot_loaf_histograms(all_histograms["MuonEntranceEnergy"]["DataFrame4"],show_provenance=True)

# %%
#with sfhe:
rdataframe_vol1 = get_rdataframe_volume_cuts(
    runspec="3500-3503",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol1_diagnostics = get_rdataframe_volume_cuts(
    runspec="3500-3503",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    tree_name="diagnostics",
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol2 = get_rdataframe_volume_cuts(
    runspec="3504-3507",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol2_diagnostics = get_rdataframe_volume_cuts(
    runspec="3504-3507",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    tree_name="diagnostics",
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol3 = get_rdataframe_volume_cuts(
    runspec="3508-3511",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol3_diagnostics = get_rdataframe_volume_cuts(
    runspec="3508-3511",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    tree_name="diagnostics",
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)

# %%
#without sfhe:
rdataframe_vol4 = get_rdataframe_volume_cuts(
    runspec="3521-3523",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol4_diagnostics = get_rdataframe_volume_cuts(
    runspec="3521-3523",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    tree_name="diagnostics",
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol5 = get_rdataframe_volume_cuts(
    runspec="3524-3527",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol5_diagnostics = get_rdataframe_volume_cuts(
    runspec="3524-3527",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    tree_name="diagnostics",
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol6 = get_rdataframe_volume_cuts(
    runspec="3528-3531",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)
rdataframe_vol6_diagnostics = get_rdataframe_volume_cuts(
    runspec="3528-3531",
    project_directory="/home/kfritzalas/tram",
    isRemoteProjectDirectory= False,
    tree_name="diagnostics",
    root_files_local_directory="/data0/kfritzalas/tram",
    xmin=-6,
    xmax=6,
    ymin=17,
    ymax=29,
    zmin=10,
    zmax=15,
    tmin=0,
    tmax=1000,
    number_of_threads=16
)

# %%
points_with_sfhe = get_ranging_points(
    muon_dataframes=[rdataframe_vol1,rdataframe_vol2,rdataframe_vol3],
    muon_number_dataframes=[rdataframe_vol1_diagnostics,rdataframe_vol2_diagnostics,rdataframe_vol3_diagnostics],
    energies=[12.0,12.5,13.0]
)
print(points_with_sfhe)

# %%
points_without_sfhe = get_ranging_points(
    muon_dataframes=[rdataframe_vol4,rdataframe_vol5,rdataframe_vol6],
    muon_number_dataframes=[rdataframe_vol4_diagnostics,rdataframe_vol5_diagnostics,rdataframe_vol6_diagnostics],
    energies=[12.0,12.5,13.0]
)
print(points_without_sfhe)

# %%
plot_ranging_points(with_sfhe=points_with_sfhe,without_sfhe=points_without_sfhe)

# %%
plot_ranging_points(with_sfhe=points_with_sfhe,without_sfhe=points_without_sfhe,save_path="test.pdf")

# %%
root_list1 = get_tram_remote_directory_root_files_list(runspec="3500-3561",print_folder_summary=False,remote_directory = "data0/leming/BT2025/kosmas/tram_new")

# %%
rdataframe = get_general_rdataframe(
    root_list1,
    "t2_points",
    number_of_threads= 8
)

# %%
rdataframe = create_rdataframe_new_column(rdataframe,
    {
        "LN3_LF3_coinc_time": "(LN3Time+LF3Time)/2",
        "RN3_RF3_coinc_time": "(RN3Time+RF3Time)/2"
    }
)

# %%
LN3_LF3_coinc_rdf = apply_global_filter(
    rdataframe,
    "(LN3Energy > 50 ) && (LF3Energy > 50 ) && (abs(LN3Time-LF3Time) < 20 )  " #adjust with correct energy cuts
)

RN3_RF3_coinc_rdf = apply_global_filter(
    rdataframe,
    "(RN3Energy > 50 ) && (RF3Energy > 50 )  && (abs(RN3Time-RF3Time) < 20 ) " #adjust with correct energy cuts
)

# %%
LN3_LF3_coinc_histograms = get_tram_histograms(
    dataframe=[
        LN3_LF3_coinc_rdf,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "LN3_LF3_coinc_time"#(LN3Time+LF3Time)/2",
    ],
    bins=[
           2000 #bin and ranges NEED to be set correctly here!
        ],
    ranges=[
            (-10000, 10000),                 
        ],
)

RN3_RF3_coinc_histograms = get_tram_histograms(
    dataframe=[
        RN3_RF3_coinc_rdf,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "RN3_RF3_coinc_time"#(LN3Time+LF3Time)/2",
        
    ],
    bins=[
            2000 #bin and ranges NEED to be set correctly here!
        ],
    ranges=[
            (-10000, 10000),                 
        ],
)

# %%
normalized_RN3_RF3_coinc_histograms = Normalize_Histograms([RN3_RF3_coinc_histograms["RN3_RF3_coinc_time"]["run 3500-3561"]])
normalized_LN3_LF3_coinc_histograms = Normalize_Histograms([LN3_LF3_coinc_histograms["LN3_LF3_coinc_time"]["run 3500-3561"]])

# %%
added_histo = addHistograms([normalized_RN3_RF3_coinc_histograms[0],normalized_LN3_LF3_coinc_histograms[0]] )

# %%
lifetime_corr_coinc = lifetime_correction_histograms(added_histo)

# %%
plot_tram_histograms(lifetime_corr_coinc, show_provenance=True)

# %%
log_histograms(lifetime_corr_coinc)

# %%
await exit_leming_browser()
