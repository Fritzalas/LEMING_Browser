# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

from mainfunctions import *
import ROOT

# Native ROOT windows
ROOT.gROOT.SetBatch(False)
ROOT.PyConfig.StartGUIThread = False
init_canvas_events()
# %jsroot off

# %%
root_list1 = get_local_directory_root_files_list(runspec="3500-3561",
                                                 print_folder_summary=False,
                                                 local_directory = "/data0/kfritzalas/tram_new")

# %%
rdataframe = get_general_rdataframe(
    root_list1,
    "t2_clusters",
    number_of_threads= 8
)

# %%
clusterY_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "Y1L",
        "Y2L",
        "Y1R",
        "Y2R"
    ],
)

# %%
plot_tram_histograms(clusterY_histograms)

# %%
clusterZ_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "Z1L",
        "Z2L",
        "Z1R",
        "Z2R"
    ],
)

# %%
plot_tram_histograms(clusterZ_histograms)

# %%
hitmaps = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "Y1L:Z1L",
        "Y1R:Z1R",
        "Y1R:Z1R",
        "Y2R:Z2R",
    ],
)

# %%
plot_tram_histograms(hitmaps)

# %%
edepZ_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "edep_Z1L",
        "edep_Z2L",
        "edep_Z1R",
        "edep_Z2R"
    ],
)

# %%
plot_tram_histograms(edepZ_histograms)

# %%
edepY_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "edep_Y1L",
        "edep_Y2L",
        "edep_Y1R",
        "edep_Y2R"
    ],
)

# %%
plot_tram_histograms(edepY_histograms)

# %%
straight_coinc_rdf = apply_global_filter(
    rdataframe,
    "(abs(Z1L-Z2L) < 0.2 )|| (abs(Z1R-Z2R) < 0.2 ) "
)

# %%
straight_coinc_histograms = get_tram_histograms(
    dataframe=[
        straight_coinc_rdf,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "Z1L",
        "Z1R",
        "Z2L",
        "Z2R"
    ],
)

# %%
plot_tram_histograms(
   {
       "Z1L": straight_coinc_histograms["Z1L"]["run 3500-3561"],
       "Z1R": straight_coinc_histograms["Z1R"]["run 3500-3561"]
   } ,
   title="Z1L & Z1R",
    show_provenance=True
)

# %%
plot_tram_histograms(straight_coinc_histograms, show_provenance=True)

# %%
coinc_rdataframe = apply_tram_straight_coincidence(
    dataframes=rdataframe,
    settings={
        # Delta Z
        "delta_z_max_left": 0.2,
        "delta_z_max_right": 0.2,

        # Z1L position
        "z1_min_left": 0.0,
        "z1_max_left": 40.0,

        # Z2L position
        "z2_min_left": 0.0,
        "z2_max_left": 40.0,

        # Z1L energy
        "z1_edep_min_left": None,
        "z1_edep_max_left": None,

        # Z2L energy
        "z2_edep_min_left": None,
        "z2_edep_max_left": None,

        # Z1L time
        "z1_time_min_left": None,
        "z1_time_max_left": None,

        # Z2L time
        "z2_time_min_left": None,
        "z2_time_max_left": None,

        # Z1R position
        "z1_min_right": 0.0,
        "z1_max_right": 40.0,

        # Z2R position
        "z2_min_right": 0.0,
        "z2_max_right": 40.0,

        # Z1R energy
        "z1_edep_min_right": None,
        "z1_edep_max_right": None,

        # Z2R energy
        "z2_edep_min_right": None,
        "z2_edep_max_right": None,

        # Z1R time
        "z1_time_min_right": None,
        "z1_time_max_right": None,

        # Z2R time
        "z2_time_min_right": None,
        "z2_time_max_right": None,
    }
)

# %%
straight_coinc_histograms = get_tram_histograms(
    dataframe=[
        coinc_rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "StraightZ1L",
        "StraightZ2L",
        "StraightZ1R",
        "StraightZ2R"
    ],
)

# %%
plot_tram_histograms(straight_coinc_histograms)

# %%
await exit_leming_browser()
