# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

from mainfunctions import *
import ROOT

# Native ROOT windows
ROOT.gROOT.SetBatch(False)
ROOT.PyConfig.StartGUIThread = False
init_canvas_events()
# %jsroot off

# %%
root_list1 = get_local_directory_root_files_list(runspec="3500-3561",
                                                 print_folder_summary=False,
                                                 local_directory = "/data0/kfritzalas/tram_new")

# %%
rdataframe = get_general_rdataframe(
    root_list1,
    "t2_clusters",
    number_of_threads= 8
)

# %%
scinti_energy_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "MuonEntranceEnergy",
        "TriggerLEnergy",
        "TriggerREnergy",
        "AtomicEnergy"
    ],
)

# %%
plot_tram_histograms(scinti_energy_histograms)

# %%
plot_tram_histograms(scinti_energy_histograms["MuonEntranceEnergy"]["run 3500-3561"],show_provenance=True)

# %%
tracker_scinti_energy_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "LN1Energy",
        "LN2Energy",
        "LN3Energy",
        "LF1Energy",
        "LF2Energy",
        "LF3Energy",
        "RN1Energy",
        "RN2Energy",
        "RN3Energy",
        "RF1Energy",
        "RF2Energy",
        "RF3Energy",
    ], saveHistograms=True, outputFileName="test"
)

# %%
plot_tram_histograms(tracker_scinti_energy_histograms)

# %%
plot_tram_histograms({
    "LF1":tracker_scinti_energy_histograms["LF1Energy"]["run 3500-3561"],
    "RF1":tracker_scinti_energy_histograms["RF1Energy"]["run 3500-3561"]
    },
    title="LF1Energy & RF1Energy",x_axis_title= "LF1Energy & RF1Energy",show_provenance=True)

# %%
scinti_time_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "MuonEntranceTime",
        "TriggerLTime",
        "TriggerRTime",
        "AtomicTime",
        "AtomicDriftTime"
    ],
)

plot_tram_histograms(scinti_time_histograms)

# %%
tracker_scinti_time_histograms = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "LN1Time",
        "LN2Time",
        "LN3Time",
        "LF1Time",
        "LF2Time",
        "LF3Time",
        "RN1Time",
        "RN2Time",
        "RN3Time",
        "RF1Time",
        "RF2Time",
        "RF3Time",
    ],
)

plot_tram_histograms(tracker_scinti_time_histograms)

# %%
plot_tram_histograms({
    "LN1_ENERGY" : tracker_scinti_energy_histograms["LN1Energy"]["run 3500-3561"],
    "RN1_ENERGY" : tracker_scinti_energy_histograms["RN1Energy"]["run 3500-3561"]
},
dataframe_label="LN1 & RN1 Energy", show_provenance=True)

# %%
added_histo = addHistograms(histograms=[tracker_scinti_energy_histograms["LN1Energy"]["run 3500-3561"],tracker_scinti_energy_histograms["RN1Energy"]["run 3500-3561"]])

# %%
plot_tram_histograms(added_histo,show_provenance=True)

# %%
twod_histo = get_tram_histograms(
    dataframe=[
        rdataframe,
    ],
    dataframe_labels=[
        "run 3500-3561",
    ],
    quantities=[
        "LN1Energy:LN1Time",
    ],
    bins = [(500, 1000)],
    ranges=[((0, 10000),(0, 4096))]
)

# %%
plot_tram_histograms(twod_histo)

# %%
await exit_leming_browser()
